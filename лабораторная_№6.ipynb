# %% [markdown]
# <a href="https://colab.research.google.com/github/alexserxio/infa_sem1/blob/master/%D0%BB%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%E2%84%966.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# Задаем территорию подстанции (координаты в метрах)
x = [100,200,200,500,500,100,100]
y = [100,100,200,200,300,300,100]
# Нарисуем подстанцию
plt.figure(1)
plt.plot(x,y)
plt.grid()
plt.xlim([0,1000])
plt.ylim([0,1000])
N =80;  # Число ударов молнии в 1 кв.км за год
 
# Отрисовка ударов молнии
for k in range(N):
  # Генерируем случайные координаты удара молнии
  x = np.random.rand()*1000
  y = np.random.rand()*1000
  if (x>=100 and x<=200 and y>=100 and y<=300) or (x>=200 and x<=500 and y>=200 and y<=300):
    plt.plot(x,y,'r+')
  else:
    plt.plot(x,y,'g+')

# %%
import numpy as np
import matplotlib.pyplot as plt
# Задаем территорию подстанции (координаты в метрах)
x = [100,200,200,500,500,100,100]
y = [100,100,200,200,300,300,100]
# Нарисуем подстанцию
plt.figure(1)
plt.plot(x,y)
plt.grid()
plt.xlim([0,1000])
plt.ylim([0,1000])
# Число ударов молнии в 1 кв.км за год
N =80
#Количество лет
I=40
#Число попаданий в ПС
P=0
K=0
#Цикл for для расчета среднего количества ударов молнии в год на территории ПС за 40 лет
for i in range(I):
# Отрисовка ударов молнии
 for k in range(N):
  # Генерируем случайные координаты удара молнии
  x = np.random.rand()*1000
  y = np.random.rand()*1000
  if (x>=100 and x<=200 and y>=100 and y<=300) or (x>=200 and x<=500 and y>=200 and y<=300):
    plt.plot(x,y,'r+')
    P=P+1
  else:
    plt.plot(x,y,'g+')
K=K+P
SR=K/I
print('Число попаданий в ПС за год',P)
print('Среднее количество молниевых ударов в год по территории подстанции за 40 лет',SR)
# Out:
# Число попаданий в ПС за год 156
# Среднее количество молниевых ударов в год по территории подстанции за 40 лет 3.9
